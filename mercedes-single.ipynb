# %%
pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 4.2 MB/s eta 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2-py3-none-any.whl (33 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.9.3 soupsieve-2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install termcolor
# Out:
# Requirement already satisfied: termcolor in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
url = "https://fiyat.mercedes-benz.com.tr/model/a-serisi/fiyat/2021"

r = requests.get(url)

soup = BeautifulSoup(r.content,"html.parser")

# %%
gelen_veri = soup.find_all("div",{"id":"accordionExample"})

# %%
gelen_veri
# Out:
# [<div _ngcontent-sc30="" class="accordion col-12 mp-0" id="accordionExample"><div _ngcontent-sc30="" class="card ddfc--a-be-befcfeeef mb-3 ng-star-inserted"><div _ngcontent-sc30="" class="card-header collapsed" data-target="#ddfc--a-be-befcfeeef" data-toggle="collapse" id="headingOne"><div _ngcontent-sc30="" class="align-items-center row after-arrow"><div _ngcontent-sc30="" class="col-12"><div _ngcontent-sc30="" class="col-lg-2 col-6 acc-headers"><span _ngcontent-sc30="">A 180</span></div><div _ngcontent-sc30="" class="col-lg-2 col-6 acc-headers f-16-set custom-position hodo"><span _ngcontent-sc30="">Style </span></div><div _ngcontent-sc30="" class="col-lg-5 col-12 acc-headers p-0"><div _ngcontent-sc30="" class="col-lg-2 col-3 float-left p-0"><img _ngcontent-sc30="" class="icon-fuel" src="../../../../assets/images/fuel@2x.png"/><span _ngcontent-sc30="" class="split-right fuel f-14-set">Benzin</span></div><div _ngcontent-sc30="" class="col-lg-4 col-5 float-left"><img _ngcontent-sc30="" class="icon-engine1" src="../../../../assets/images/engine-1@2x.png"/><span _ngcontent-sc30="" class="split-right engine f-14-set">1.332 cm<sup _ngcontent-sc30="">3</sup></span></div><div _ngcontent-sc30="" class="col-lg-3 col-4 float-left p-0"><img _ngcontent-sc30="" class="icon-engine2" src="../../../../assets/images/engine-2@2x.png"/><span _ngcontent-sc30="" class="split-right torque f-14-set">136 bg</span></div><div _ngcontent-sc30="" class="col-lg-3 d-none d-lg-block d-lg-block float-left p-0"><img _ngcontent-sc30="" class="icon-engine2" src="../../../../assets/images/gear-engine-pc@2x.png"/><span _ngcontent-sc30="" class="split-right f-14-set">7G-DCT</span></div></div><div _ngcontent-sc30="" class="col-lg-2 col-6 acc-headers advice-price pl-0 pr-5"><span _ngcontent-sc30="">Tavsiye Edilen Anahtar Teslim Fiyatı</span></div><div _ngcontent-sc30="" class="col-lg-1 col-6 acc-headers p-0"><span _ngcontent-sc30="" class="d-block text-center pull-left-md txt-demi f-18"> TL</span></div></div></div></div><div _ngcontent-sc30="" aria-labelledby="headingOne" class="collapse" data-parent="#accordionExample" id="ddfc--a-be-befcfeeef"><div _ngcontent-sc30="" class="card-body row"><div _ngcontent-sc30="" class="col-12 custom-p"><div _ngcontent-sc30="" class="d-none show-on-mobile col-lg-4 col-12 pull-right mp-0"><div _ngcontent-sc30="" class="col-lg-auto col-8 pull-left mp-0"><p _ngcontent-sc30="">Şanzıman Tipi</p></div><div _ngcontent-sc30="" class="col-lg-auto col-4 pull-right mp-0"><p _ngcontent-sc30="">7G-DCT</p></div></div></div><div _ngcontent-sc30="" class="col-12 custom-p"><div _ngcontent-sc30="" class="col-lg-4 col-12 pull-right mp-0"><div _ngcontent-sc30="" class="col-lg-auto col-8 pull-left mp-0"><p _ngcontent-sc30="">Liste Fiyatı Vergiler Hariç</p></div><div _ngcontent-sc30="" class="col-lg-auto col-4 pull-right mp-0"><p _ngcontent-sc30="">  TL </p></div></div></div><div _ngcontent-sc30="" class="col-12 custom-p"><div _ngcontent-sc30="" class="col-lg-4 col-12 pull-right mp-0"><div _ngcontent-sc30="" class="col-lg-auto col-8 pull-left mp-0"><p _ngcontent-sc30="">ÖTV Oranı</p></div><div _ngcontent-sc30="" class="col-lg-auto col-4 pull-right mp-0"><p _ngcontent-sc30="">% 80</p></div></div></div><div _ngcontent-sc30="" class="col-12 custom-p"><div _ngcontent-sc30="" class="col-lg-4 col-12 pull-right mp-0"><div _ngcontent-sc30="" class="col-lg-auto col-8 pull-left mp-0"><p _ngcontent-sc30="">Tescil Masrafları</p></div><div _ngcontent-sc30="" class="col-lg-auto col-4 pull-right mp-0"><p _ngcontent-sc30=""> 0 TL </p></div></div></div></div><div _ngcontent-sc30="" class="row accordion-sub-buttons"><a _ngcontent-sc30="" class="a-180-style-2020compare acc-headers col-lg col-md-12 d-flex justify-content-center"><img _ngcontent-sc30="" class="comparison" src="../../../../assets/images/pc-comparison@2x.png"/><span _ngcontent-sc30="" class="split-right pt-1">Karşılaştırmaya Ekle</span></a><!-- --><a _ngcontent-sc30="" class="a-180-style-2020payment acc-heade ...

# %%
satirlar = gelen_veri[0]

# %%
satirlar
# Out:
# <div _ngcontent-sc30="" class="accordion col-12 mp-0" id="accordionExample"><div _ngcontent-sc30="" class="card ddfc--a-be-befcfeeef mb-3 ng-star-inserted"><div _ngcontent-sc30="" class="card-header collapsed" data-target="#ddfc--a-be-befcfeeef" data-toggle="collapse" id="headingOne"><div _ngcontent-sc30="" class="align-items-center row after-arrow"><div _ngcontent-sc30="" class="col-12"><div _ngcontent-sc30="" class="col-lg-2 col-6 acc-headers"><span _ngcontent-sc30="">A 180</span></div><div _ngcontent-sc30="" class="col-lg-2 col-6 acc-headers f-16-set custom-position hodo"><span _ngcontent-sc30="">Style </span></div><div _ngcontent-sc30="" class="col-lg-5 col-12 acc-headers p-0"><div _ngcontent-sc30="" class="col-lg-2 col-3 float-left p-0"><img _ngcontent-sc30="" class="icon-fuel" src="../../../../assets/images/fuel@2x.png"/><span _ngcontent-sc30="" class="split-right fuel f-14-set">Benzin</span></div><div _ngcontent-sc30="" class="col-lg-4 col-5 float-left"><img _ngcontent-sc30="" class="icon-engine1" src="../../../../assets/images/engine-1@2x.png"/><span _ngcontent-sc30="" class="split-right engine f-14-set">1.332 cm<sup _ngcontent-sc30="">3</sup></span></div><div _ngcontent-sc30="" class="col-lg-3 col-4 float-left p-0"><img _ngcontent-sc30="" class="icon-engine2" src="../../../../assets/images/engine-2@2x.png"/><span _ngcontent-sc30="" class="split-right torque f-14-set">136 bg</span></div><div _ngcontent-sc30="" class="col-lg-3 d-none d-lg-block d-lg-block float-left p-0"><img _ngcontent-sc30="" class="icon-engine2" src="../../../../assets/images/gear-engine-pc@2x.png"/><span _ngcontent-sc30="" class="split-right f-14-set">7G-DCT</span></div></div><div _ngcontent-sc30="" class="col-lg-2 col-6 acc-headers advice-price pl-0 pr-5"><span _ngcontent-sc30="">Tavsiye Edilen Anahtar Teslim Fiyatı</span></div><div _ngcontent-sc30="" class="col-lg-1 col-6 acc-headers p-0"><span _ngcontent-sc30="" class="d-block text-center pull-left-md txt-demi f-18"> TL</span></div></div></div></div><div _ngcontent-sc30="" aria-labelledby="headingOne" class="collapse" data-parent="#accordionExample" id="ddfc--a-be-befcfeeef"><div _ngcontent-sc30="" class="card-body row"><div _ngcontent-sc30="" class="col-12 custom-p"><div _ngcontent-sc30="" class="d-none show-on-mobile col-lg-4 col-12 pull-right mp-0"><div _ngcontent-sc30="" class="col-lg-auto col-8 pull-left mp-0"><p _ngcontent-sc30="">Şanzıman Tipi</p></div><div _ngcontent-sc30="" class="col-lg-auto col-4 pull-right mp-0"><p _ngcontent-sc30="">7G-DCT</p></div></div></div><div _ngcontent-sc30="" class="col-12 custom-p"><div _ngcontent-sc30="" class="col-lg-4 col-12 pull-right mp-0"><div _ngcontent-sc30="" class="col-lg-auto col-8 pull-left mp-0"><p _ngcontent-sc30="">Liste Fiyatı Vergiler Hariç</p></div><div _ngcontent-sc30="" class="col-lg-auto col-4 pull-right mp-0"><p _ngcontent-sc30="">  TL </p></div></div></div><div _ngcontent-sc30="" class="col-12 custom-p"><div _ngcontent-sc30="" class="col-lg-4 col-12 pull-right mp-0"><div _ngcontent-sc30="" class="col-lg-auto col-8 pull-left mp-0"><p _ngcontent-sc30="">ÖTV Oranı</p></div><div _ngcontent-sc30="" class="col-lg-auto col-4 pull-right mp-0"><p _ngcontent-sc30="">% 80</p></div></div></div><div _ngcontent-sc30="" class="col-12 custom-p"><div _ngcontent-sc30="" class="col-lg-4 col-12 pull-right mp-0"><div _ngcontent-sc30="" class="col-lg-auto col-8 pull-left mp-0"><p _ngcontent-sc30="">Tescil Masrafları</p></div><div _ngcontent-sc30="" class="col-lg-auto col-4 pull-right mp-0"><p _ngcontent-sc30=""> 0 TL </p></div></div></div></div><div _ngcontent-sc30="" class="row accordion-sub-buttons"><a _ngcontent-sc30="" class="a-180-style-2020compare acc-headers col-lg col-md-12 d-flex justify-content-center"><img _ngcontent-sc30="" class="comparison" src="../../../../assets/images/pc-comparison@2x.png"/><span _ngcontent-sc30="" class="split-right pt-1">Karşılaştırmaya Ekle</span></a><!-- --><a _ngcontent-sc30="" class="a-180-style-2020payment acc-header ...

# %%
bilgiler = satirlar.find_all("span")

modelSatiri = satirlar.find_all("div",{"class":"col-lg-2 col-6 acc-headers"})
paketSatiri = satirlar.find_all("div",{"col-lg-2 col-6 acc-headers f-16-set custom-position hodo"})

yakitSatiri = satirlar.find_all("span",{"class":"split-right fuel f-14-set"})
motorSatiri = satirlar.find_all("span",{"class":"split-right engine f-14-set"})
beygirSatiri = satirlar.find_all("span",{"class":"split-right torque f-14-set"})
sanzumanSatiri = satirlar.find_all("span",{"class":"split-right f-14-set"})
fiyatSatiri = satirlar.find_all("span",{"class":"d-block text-center pull-left-md txt-demi f-18"})

# %%
from termcolor import colored
for fiyatBilgi,yakitBilgi,motorBilgi,beygirBilgi,sanzumanBilgi,modelBilgi,paketBilgi in zip(fiyatSatiri,yakitSatiri,motorSatiri,beygirSatiri,sanzumanSatiri,modelSatiri,paketSatiri):
    fiyat = fiyatBilgi
    yakit = yakitBilgi
    motor = motorBilgi
    beygir = beygirBilgi
    sanzuman = sanzumanBilgi
    model = modelBilgi
    paket = paketBilgi
    print(colored(model.text,"red") if fiyat.text == " TL" else model.text,paket.text,yakit.text,motor.text,beygir.text,sanzuman.text,colored(fiyat.text,"green"))
# Out:
# A 180 Style  Benzin 1.332 cm3 136 bg 7G-DCT  TL
# A 200 AMG  Benzin 1.332 cm3 163 bg 7G-DCT  TL
# A 200 AMG  Benzin 1.332 cm3 163 bg 7G-DCT 475.700 TL
# Mercedes-AMG A 35 4MATIC Performance  Benzin 1.991 cm3 306 bg AMG SPEEDSHIFT DCT 965.300 TL
# Mercedes-AMG A 45 S 4MATIC+ Performance  Benzin 1.991 cm3 421 bg AMG SPEEDSHIFT DCT 1.280.800 TL
